# %% [markdown]
# This notebook is used for analysing the data extracted from studies belonging to TOM Project.

# %% [markdown]
# # Settings

# %% [markdown]
# ## Install Libs

# %% [markdown]
# Install some useful Libs.

# %%
# !pip install tikzplotlib==0.9.9 -q
# !pip install pyvis -q
# !pip install network2tikz -q
# Out:
#      |████████████████████████████████| 53 kB 1.2 MB/s
#   Building wheel for pyvis (setup.py) ... done
#      |████████████████████████████████| 41 kB 80 kB/s

# %% [markdown]
# ## Import Libs

# %% [markdown]
# Import the libs used for data analysis

# %%
import pandas as pd
import numpy as np
import altair as altair
import matplotlib.pyplot as plt
plt.style.use("default")

import urllib


from pyvis.network import Network

from IPython.core.display import display, HTML, display_latex
from network2tikz import plot

import networkx as nx

import itertools

# %% [markdown]
# # Preparation

# %% [markdown]
# ## Importing and Exploring the Data

# %% [markdown]
# We import the data.

# %%
sheet_name = "DATA"
data = pd.read_csv('https://docs.google.com/spreadsheets/d/13RhQTl8ku2OCeXvp3U5zI_W3kWQdXDolXR3G-XT3_DI/gviz/tq?tqx=out:csv&sheet={}'.format(urllib.parse.quote(sheet_name)))


metrics_col_name = "Metric"
anomalies_col_name = "Anomaly"
actions_col_name = "Suggested Action"


def data_info(data = data):

  metrics_count = data[metrics_col_name].nunique()
  anomalies_count = data[anomalies_col_name].nunique()
  actions_count = data[actions_col_name].nunique()
  n = data["Study"].nunique()
  info = pd.DataFrame()

  print()
  print("This data includes {0} Metrics, {1} Anomalies and {2} Actions from {3} studies. In total, {4} data points.".
      format(metrics_count, anomalies_count, actions_count, n, sum([metrics_count, anomalies_count, actions_count])))

data_info(data)

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Preliminary Study Clustering

# %% [markdown]
# ### Distribution of studies by country of origin based on first author’s affiliation

# %% [markdown]
# Distribution

# %%
data[['Country',"Study"]].drop_duplicates().groupby(["Country"]).count().sort_values("Study",ascending = False)
# Out:
#            Study
# Country
# USA           16
# India         12
# China          4
# Finland        4
# Brazil         3
# Canada         3
# England        3
# Australia      2
# Germany        2
# Belgium        1
# Italy          1
# Japan          1
# Malaysia       1
# Norway         1
# Spain          1
# Sweden         1
# Taiwan         1
# Iran           1

# %% [markdown]
# Country Count

# %%
data['Country'].unique().size
# Out:
# 18

# %% [markdown]
# ### Distribution of studies by year of publication

# %% [markdown]
# Distribution

# %%
data[['Publication year',"Study"]].drop_duplicates().groupby(["Publication year"]).count().sort_values("Publication year",ascending = False)
# Out:
#                   Study
# Publication year
# 2020                  5
# 2019                  2
# 2018                  4
# 2017                  4
# 2016                  1
# 2015                  2
# 2014                  2
# 2013                  5
# 2012                  2
# 2011                  2
# 2010                  4
# 2009                  1
# 2006                  5
# 2005                  1
# 2004                  1
# 2003                  1
# 2002                  1
# 2001                  1
# 1999                  2
# 1997                  1
# 1995                  1
# 1993                  1
# 1991                  1
# 1990                  3
# 1989                  2
# 1988                  1
# 1986                  1
# 1981                  1

# %% [markdown]
# Study count and percentage in last 10 years

# %%
study_total_count = data['Study'].nunique()

study_count_last_10_years = data[['Publication year',"Study"]].drop_duplicates().groupby(["Publication year"]).count().sort_values("Publication year",ascending = False)[:11].sum()[0]

study_total_count, study_count_last_10_years, study_count_last_10_years / study_total_count
# Out:
# (58, 33, 0.5689655172413793)

# %% [markdown]
# ### Distribution of studies by type of publication

# %% [markdown]
# Distribution

# %%
data[['Publication type',"Study"]].drop_duplicates().groupby(["Publication type"]).count().sort_values("Publication type",ascending = False)
# Out:
#                   Study
# Publication type
# Journal              39
# Conference           19

# %% [markdown]
# Publication Type percentage

# %%
study_total_count = data['Study'].nunique()

publication_type_data = data[['Publication type',"Study"]].drop_duplicates().groupby(["Publication type"]).count().sort_values("Publication type",ascending = False)


publication_type_data['Percentage'] = publication_type_data.apply(lambda x: round(x/study_total_count,2))
publication_type_data
# Out:
#                   Study  Percentage
# Publication type
# Journal              39        0.67
# Conference           19        0.33

# %% [markdown]
# ## Individual Data analysis

# %% [markdown]
# ### Excluding data from Study "S53"

# %% [markdown]
# We select only important data by excluding S53.

# %%
# We will fill empty cells of columns related to the study.
data1 = data
data = data1.drop(data[data['Study']=='S53'].index)
# data = data.drop(data[data['Study']=='S'].index)


# data = data.drop(data.loc[data['Anomaly'].str.contains('not specified').dropna().index[np.where(data['Anomaly'].str.contains('not specified').dropna())]].index)
# data = data.drop(data.loc[data['Suggested Action'].str.contains('not specified').dropna().index[np.where(data['Suggested Action'].str.contains('not specified').dropna())]].index)


# data
data_info(data)
# Out:
# This data includes 384 Metrics, 374 Anomalies and 494 Actions from 57 studies. In total, 1252 data points.

# %% [markdown]
# ### Generate Stats Table

# %% [markdown]
# Citation Info of studies

# %%
tom_citation = '''
hendis1981quantifying
nassar1986software
kitchenham1989quantitative
fox1989performance
mays1990experiences
card1988software
porter1990empirically
mays1990applications
boehm1991software
bhandari1993case
zage1995avoiding
lane1997intergrating
travassos1999detecting
ebert1999technical
mohapatra2001defect
leszak2002classification
younessi2003managing
wallace2004software
jalote2005using
wang2006bsr
chambers2006hazard
liu2006intelligent
white2006external
song2006software
shenvi2009defect
tsunoda2010modeling
bjorndal2010global
kapova2010evaluating
kumaresh2010defect
chowdhury2011using
nayak2012reliable
kumaresh2012experimental
kumaresh2012defect
dalal2013empirical
oyetoyan2013study
chang2013integrating
kumaresh2013software
fatima2013improving
lehtinen2014perceived
korkala2014waste
lavallee2015good
lehtinen2015development
yan2016automatically
kumar2017empirical
lehtinen2017recurring
shi2017metric
hu2017defect
freire2018bayesian
treude2018unusual
saini2018change
brito2018investigating
zong2019classification
caulo2020taxonomy
anastassiu2020resistance
mas2020supporting
saidani2020predicting
kolahdouz2020technical
abaei2020fuzzy
'''



citation = tom_citation.split("\n")[+1:-1]

# studies = [S]
studies = ["S" + str(d+1).zfill(2) for d in range(len(citation))]
study_mapping = dict(zip(studies, citation))
study_mapping
# Out:
# {'S01': 'hendis1981quantifying',
#  'S02': 'nassar1986software',
#  'S03': 'kitchenham1989quantitative',
#  'S04': 'fox1989performance',
#  'S05': 'mays1990experiences',
#  'S06': 'card1988software',
#  'S07': 'porter1990empirically',
#  'S08': 'mays1990applications',
#  'S09': 'boehm1991software',
#  'S10': 'bhandari1993case',
#  'S11': 'zage1995avoiding',
#  'S12': 'lane1997intergrating',
#  'S13': 'travassos1999detecting',
#  'S14': 'ebert1999technical',
#  'S15': 'mohapatra2001defect',
#  'S16': 'leszak2002classification',
#  'S17': 'younessi2003managing',
#  'S18': 'wallace2004software',
#  'S19': 'jalote2005using',
#  'S20': 'wang2006bsr',
#  'S21': 'chambers2006hazard',
#  'S22': 'liu2006intelligent',
#  'S23': 'white2006external',
#  'S24': 'song2006software',
#  'S25': 'shenvi2009defect',
#  'S26': 'tsunoda2010modeling',
#  'S27': 'bjorndal2010global',
#  'S28': 'kapova2010evaluating',
#  'S29': 'kumaresh2010defect',
#  'S30': 'chowdhury2011using',
#  'S31': 'nayak2012reliable',
#  'S32': 'kumaresh2012experimental',
#  'S33': 'kumaresh2012defect',
#  'S34': 'dalal2013empirical',
#  'S35': 'oyetoyan2013study',
#  'S36': 'chang2013integrating',
#  'S37': 'kumaresh2013software',
#  'S38': 'fatima2013improving',
#  'S39': 'lehtinen2014perceived',
#  'S40': 'korkala2014waste',
#  'S41': 'lavallee2015good',
#  'S42': 'lehtinen2015development',
#  'S43': 'yan2016automatically',
#  'S44': 'kumar2017empirical',
#  'S45': 'lehtinen2017recurring',
#  'S46': 'shi2017metric',
#  'S47': 'hu2017defect',
#  'S48': 'freire2018bayesian',
#  'S49': 'treude2018unusual',
#  'S50': 'saini2018change',
#  'S51': 'brito2018investigating',
#  'S52': 'zong2019classification',
#  'S53': 'caulo2020taxonomy',
#  'S54': 'anastassiu2020resistance',
#  'S55': 'mas2020supporting',
#  'S56': 'saidani2020predicting',
#  'S57': 'kolahdouz2020technical',
#  'S58': 'abaei2020fuzzy'}

# %%
'''
Returns the citation of studies
'''
def study2citation(list_of_studies):
  list_of_citations = []
  for s in list_of_studies:
    list_of_citations.append(study_mapping[s])

  return list_of_citations


study2citation(['S01','S02'])
# Out:
# ['hendis1981quantifying', 'nassar1986software']

# %%
'''
Returns statistics dataframe about the connections among all data types.

'''
def stats(data1, latex_file_name = "stats.tex"):

  data = data1[['Study', metrics_col_name, anomalies_col_name,actions_col_name]].dropna(how="all").drop_duplicates()
  counts = [] 

  df = pd.DataFrame(columns = ['Samples','Metrics', 'Anomalies', 'Actions', 'Metric-Anomaly', 'Anomaly-Action', 'Metric-Action', 'Metric-Anomaly-Action'], index = np.append(np.append(data['Study'].unique(),"Total"), "Count") )
  for study in data['Study'].unique():
    df.at[study, df.columns[0]] = len(data[data['Study']==study])

    df.at[study, df.columns[1]] = data[data['Study']==study][metrics_col_name].nunique()
    df.at[study, df.columns[2]] = data[data['Study']==study][anomalies_col_name].nunique()
    df.at[study, df.columns[3]] = data[data['Study']==study][actions_col_name].nunique()


    col1 = metrics_col_name
    col2 = anomalies_col_name
    mask = data[data['Study']==study][col1].notnull()&data[data['Study']==study][col2].notnull()
    mn = len(data.iloc[np.where(mask)[0]])
    df.at[study, df.columns[4]] = mn
    

    col2 = actions_col_name
    col1 = anomalies_col_name
    mask = data[data['Study']==study][col1].notnull()&data[data['Study']==study][col2].notnull()
    mn = len(data.iloc[np.where(mask)[0]])
    df.at[study, df.columns[5]] = mn



    col1 = metrics_col_name
    col2 = actions_col_name
    mask = data[data['Study']==study][col1].notnull()&data[data['Study']==study][col2].notnull()  #&data[data['Study']==study][anomalies_col_name].isna()
    mn = len(data.iloc[np.where(mask)[0]])
    df.at[study, df.columns[6]] = mn

    col1 = metrics_col_name
    col2 = actions_col_name
    col3 = anomalies_col_name
    mask = data[data['Study']==study][col1].notnull()&data[data['Study']==study][col2].notnull()&data[data['Study']==study][col3].notnull()
    mn = len(data.iloc[np.where(mask)[0]])
    df.at[study, df.columns[7]] = mn
    


  v = data[metrics_col_name].nunique()
  counts.append(v)
  
  v = data[anomalies_col_name].nunique()
  counts.append(v)


  v = data[actions_col_name].nunique()
  counts.append(v)


  v = (data[metrics_col_name] + data[anomalies_col_name]).nunique()
  counts.append(v)


  v = (data[anomalies_col_name] + data[actions_col_name]).nunique() 
  counts.append(v)

  # dd = data[[metrics_col_name, actions_col_name]].drop_duplicates().dropna()
# dd = data.loc[data[anomalies_col_name].isna().index][[metrics_col_name, actions_col_name]].drop_duplicates().dropna()
  # v = dd.nunique()[0]
  v = (data[actions_col_name] + data[metrics_col_name]).nunique()
  counts.append(v)

  v = (data[metrics_col_name] + data[anomalies_col_name] + data[actions_col_name]).nunique()
  counts.append(v)

  

  T = (data[metrics_col_name].fillna("") + data[anomalies_col_name].fillna("") + data[actions_col_name].fillna("")).nunique()

  counts.insert(0,T)
   
  for col in df.columns:
    df.at["Total", col] = df[col].sum()
  
  df.at["Count", :] = counts

  df.replace(0, "", inplace=True)
  
  # Exclude the study S53
  citation_app = citation
  if "caulo2020taxonomy" in citation_app:
    citation_app.remove("caulo2020taxonomy")

  citation_app = np.append(np.append(citation_app,"Total"), "Count") 

  df.index = map(lambda x: str('\citet{'+x+'}') if (x!="Total" or x!="Count") else x, citation_app)
 
  if (latex_file_name):
    df.to_latex(latex_file_name, escape = False, na_rep = "0")
  

  return df


df = stats(data, "stats.tex")


df
# Out:
#                                     Samples Metrics Anomalies Actions  \
# \citet{hendis1981quantifying}             9       2         7
# \citet{nassar1986software}               14       4                10
# \citet{kitchenham1989quantitative}       46      29         4      17
# \citet{fox1989performance}                4       1         4       4
# \citet{mays1990experiences}              18                 4      18
# \citet{card1988software}                 20      15         1       5
# \citet{porter1990empirically}             4       4         1
# \citet{mays1990applications}              2                 2       2
# \citet{boehm1991software}                10                10      10
# \citet{bhandari1993case}                  9       9         7       7
# \citet{zage1995avoiding}                  5       2                 5
# \citet{lane1997intergrating}             10       6         3       7
# \citet{travassos1999detecting}            5                 5       1
# \citet{ebert1999technical}               19      19         1       1
# \citet{mohapatra2001defect}              18       4        17      18
# \citet{leszak2002classification}          8       3         5       8
# \citet{younessi2003managing}             41                11      39
# \citet{wallace2004software}              78                78
# \citet{jalote2005using}                   7       1         1       7
# \citet{wang2006bsr}                       4       3         4       1
# \citet{chambers2006hazard}               30                16      25
# \citet{liu2006intelligent}                7       7         3
# \citet{white2006external}                40                        40
# \citet{song2006software}                  9       3         6
# \citet{shenvi2009defect}                  9       5         6       4
# \citet{tsunoda2010modeling}               8       4         8       6
# \citet{bjorndal2010global}                1       1
# \citet{kapova2010evaluating}             35      35
# \citet{kumaresh2010defect}               14       1         5      14
# \citet{chowdhury2011using}               13      13         1
# \citet{nayak2012reliable}                28                20      13
# \citet{kumaresh2012experimental}         40       2        22      39
# \citet{kumaresh2012defect}               30       1        30      30
# \citet{dalal2013empirical}                9       5         7       1
# \citet{oyetoyan2013study}                 7       7         1       1
# \citet{chang2013integrating}             10      10
# \citet{kumaresh2013software}             21                12      21
# \citet{fatima2013improving}               4                 4       4
# \citet{lehtinen2014perceived}            20                20
# \citet{korkala2014waste}                  4       3         4       4
# \citet{lavallee2015good}                 21      11        10      10
# \citet{lehtinen2015development}          29                 9      16
# \citet{yan2016automatically}              1       1
# \citet{kumar2017empirical}               18      18         1
# \citet{lehtinen2017recurring}            34                 5      34
# \citet{shi2017metric}                    13      13
# \citet{hu2017defect}                     12      12         6       1
# \citet{freire2018bayesian}               17      17        17
# \citet{treude2018unusual}                25      18         3
# \citet{saini2018change}                   5       5
# \citet{brito2018investigating}          140      80                47
# \citet{zong2019classification}           11      11
# \citet{anastassiu2020resistance}         30                 1      29
# \citet{mas2020supporting}                 7       7
# \citet{saidani2020predicting}            33      33         1
# \citet{kolahdouz2020technical}            5       4         3
# \citet{abaei2020fuzzy}                    6       6         1
# \citet{Total}                          1077     435       387     499
# \citet{Count}                          1063     384       374     494
#
#                                    Metric-Anomaly Anomaly-Action  \
# \citet{hendis1981quantifying}
# \citet{nassar1986software}
# \citet{kitchenham1989quantitative}                            17
# \citet{fox1989performance}                      1              4
# \citet{mays1990experiences}                                   18
# \citet{card1988software}                                       1
# \citet{porter1990empirically}                   4
# \citet{mays1990applications}                                   2
# \citet{boehm1991software}                                     10
# \citet{bhandari1993case}                        9              9
# \citet{zage1995avoiding}
# \citet{lane1997intergrating}                    7              7
# \citet{travassos1999detecting}                                 5
# \citet{ebert1999technical}                      1              1
# \citet{mohapatra2001defect}                     4             18
# \citet{leszak2002classification}                1              5
# \citet{younessi2003managing}                                  22
# \citet{wallace2004software}
# \citet{jalote2005using}                         1              1
# \citet{wang2006bsr}                             3              3
# \citet{chambers2006hazard}                                    30
# \citet{liu2006intelligent}                      3
# \citet{white2006external}
# \citet{song2006software}
# \citet{shenvi2009defect}                        4              4
# \citet{tsunoda2010modeling}                     8              7
# \citet{bjorndal2010global}
# \citet{kapova2010evaluating}
# \citet{kumaresh2010defect}                     14             14
# \citet{chowdhury2011using}                     13
# \citet{nayak2012reliable}                                     28
# \citet{kumaresh2012experimental}                2             40
# \citet{kumaresh2012defect}                     30             30
# \citet{dalal2013empirical}                      7              1
# \citet{oyetoyan2013study}                       3              3
# \citet{chang2013integrating}
# \citet{kumaresh2013software}                                  21
# \citet{fatima2013improving}                                    4
# \citet{lehtinen2014perceived}
# \citet{korkala2014waste}                        3              4
# \citet{lavallee2015good}                       20             21
# \citet{lehtinen2015development}                               29
# \citet{yan2016automatically}
# \citet{kumar2017empirical}                     18
# \citet{lehtinen2017recurring}                                 34
# \citet{shi2017metric}
# \citet{hu2017defect}                            6              6
# \citet{freire2018bayesian}                     17
# \citet{treude2018unusual}                      25
# \citet{saini2018change}
# \citet{brito2018investigating}
# \citet{zong2019classification}
# \citet{anastassiu2020resistance}                              29
# \citet{mas2020supporting}
# \citet{saidani2020predicting}                  33
# \citet{kolahdouz2020technical}                  3
# \citet{abaei2020fuzzy}                          6
# \citet{Total}                                 246            428
# \citet{Count}                                 233            409
#
#                                    Metric-Action Metric-Anomaly-Action
# \citet{hendis1981quantifying}
# \citet{nassar1986software}                     1
# \citet{kitchenham1989quantitative}
# \citet{fox1989performance}                     1                     1
# \citet{mays1990experiences}
# \citet{card1988software}
# \citet{porter1990empirically}
# \citet{mays1990applications}
# \citet{boehm1991software}
# \citet{bhandari1993case}                       9                     9
# \citet{zage1995avoiding}                       2
# \citet{lane1997intergrating}                   7                     7
# \citet{travassos1999detecting}
# \citet{ebert1999technical}                     1                     1
# \citet{mohapatra2001defect}                    4                     4
# \citet{leszak2002classification}               3                     1
# \citet{younessi2003managing}
# \citet{wallace2004software}
# \citet{jalote2005using}                        1                     1
# \citet{wang2006bsr}                            3                     3
# \citet{chambers2006hazard}
# \citet{liu2006intelligent}
# \citet{white2006external}
# \citet{song2006software}
# \citet{shenvi2009defect}
# \citet{tsunoda2010modeling}                    7                     7
# \citet{bjorndal2010global}
# \citet{kapova2010evaluating}
# \citet{kumaresh2010defect}                    14                    14
# \citet{chowdhury2011using}
# \citet{nayak2012reliable}
# \citet{kumaresh2012experimental}               2                     2
# \citet{kumaresh2012defect}                    30                    30
# \citet{dalal2013empirical}
# \citet{oyetoyan2013study}                      3                     3
# \citet{chang2013integrating}
# \citet{kumaresh2013software}
# \citet{fatima2013improving}
# \citet{lehtinen2014perceived}
# \citet{korkala2014waste}                       3                     3
# \citet{lavallee2015good}                      20                    20
# \citet{lehtinen2015development}
# \citet{yan2016automatically}
# \citet{kumar2017empirical}
# \citet{lehtinen2017recurring}
# \citet{shi2017metric}
# \citet{hu2017defect}                           6                     6
# \citet{freire2018bayesian}
# \citet{treude2018unusual}
# \citet{saini2018change}
# \citet{brito2018investigating}               133
# \citet{zong2019classification}
# \citet{anastassiu2020resistance}
# \citet{mas2020supporting}
# \citet{saidani2020predicting}
# \citet{kolahdouz2020technical}
# \citet{abaei2020fuzzy}
# \citet{Total}                                250                   112
# \citet{Count}                                250                   112

# %%
assert not any(data['Study']=='S53'), "Study S53 should be removed since it is an outlier"

# %% [markdown]
# ### Metrics Data

# %% [markdown]
# #### Metrics

# %% [markdown]
# Metric distribution in studies

# %%
temp = data[['Metric','Study']].drop_duplicates().dropna().groupby("Metric").count().sort_values("Study",ascending=False).head(15)

temp['Studies'] = None
temp['Citation'] = None

for s in temp.index:
  temp.at[s, 'Studies'] = data[data['Metric']==s]['Study'].unique()
  temp.at[s, 'Citation'] = study2citation(data[data['Metric']==s]['Study'].unique())

print(temp.to_string())
# Out:
#                                        Study                                                       Studies                                                                                                                                                                                                                                                      Citation
# Metric
# loc                                       12  [S02, S03, S06, S07, S12, S14, S28, S30, S44, S49, S52, S58]  [nassar1986software, kitchenham1989quantitative, card1988software, porter1990empirically, lane1997intergrating, ebert1999technical, kapova2010evaluating, chowdhury2011using, kumar2017empirical, treude2018unusual, zong2019classification, abaei2020fuzzy]
# cyclomatic complexity                      7                           [S03, S06, S07, S30, S44, S46, S58]                                                                                                                  [kitchenham1989quantitative, card1988software, porter1990empirically, chowdhury2011using, kumar2017empirical, shi2017metric, abaei2020fuzzy]
# # change requests                          6                                [S03, S06, S40, S41, S46, S49]                                                                                                                                          [kitchenham1989quantitative, card1988software, korkala2014waste, lavallee2015good, shi2017metric, treude2018unusual]
# coupling between object classes (cbo)      4                                          [S30, S35, S44, S57]                                                                                                                                                                           [chowdhury2011using, oyetoyan2013study, kumar2017empirical, kolahdouz2020technical]
# defect density                             4                                          [S26, S29, S46, S51]                                                                                                                                                                              [tsunoda2010modeling, kumaresh2010defect, shi2017metric, brito2018investigating]
# documentation size                         4                                          [S03, S06, S25, S41]                                                                                                                                                                            [kitchenham1989quantitative, card1988software, shenvi2009defect, lavallee2015good]
# fan-out                                    3                                               [S03, S30, S57]                                                                                                                                                                                      [kitchenham1989quantitative, chowdhury2011using, kolahdouz2020technical]
# productivity in function points            3                                               [S12, S15, S51]                                                                                                                                                                                           [lane1997intergrating, mohapatra2001defect, brito2018investigating]
# response for class (rfc)                   3                                               [S30, S35, S44]                                                                                                                                                                                                   [chowdhury2011using, oyetoyan2013study, kumar2017empirical]
# fan-in                                     3                                               [S03, S30, S57]                                                                                                                                                                                      [kitchenham1989quantitative, chowdhury2011using, kolahdouz2020technical]
# # defects                                  3                                               [S10, S16, S26]                                                                                                                                                                                             [bhandari1993case, leszak2002classification, tsunoda2010modeling]
# effort                                     3                                               [S14, S15, S24]                                                                                                                                                                                                   [ebert1999technical, mohapatra2001defect, song2006software]
# number of children (noc)                   2                                                    [S30, S44]                                                                                                                                                                                                                      [chowdhury2011using, kumar2017empirical]
# depth of inheritance tree (dit)            2                                                    [S30, S44]                                                                                                                                                                                                                      [chowdhury2011using, kumar2017empirical]
# cycle time                                 2                                                    [S12, S55]                                                                                                                                                                                                                     [lane1997intergrating, mas2020supporting]

# %% [markdown]
# Studies of "loc" metric

# %%
studies_loc_metric = data[data['Metric']=='loc'][['Study', "Metric"]].drop_duplicates()
studies_loc_metric = [study_mapping[key] for key in studies_loc_metric['Study']]
studies_loc_metric
# Out:
# ['nassar1986software',
#  'kitchenham1989quantitative',
#  'card1988software',
#  'porter1990empirically',
#  'lane1997intergrating',
#  'ebert1999technical',
#  'kapova2010evaluating',
#  'chowdhury2011using',
#  'kumar2017empirical',
#  'treude2018unusual',
#  'zong2019classification',
#  'abaei2020fuzzy']

# %% [markdown]
# Study Count which provided metrics

# %%
data[['Metric','Study']].dropna()['Study'].nunique() # + 1 # The study that we removed from our results S53
# Out:
# 42

# %% [markdown]
# Metric count of S53 (Caulo et al. 2020)

# %%
data1[data1['Study']=='S53']['Raw metric'].nunique()
# Out:
# 509

# %% [markdown]
# Total Metric count

# %%
data[['Metric']].nunique()
# Out:
# Metric    384
# dtype: int64

# %% [markdown]
# Metric category count

# %%
metric_category_dist = data[['Metric category','Metric']].dropna(how='all').drop_duplicates().groupby("Metric category").count()
metrics_count = data[['Metric']].nunique()[0]

metric_category_dist['Percentage'] = metric_category_dist['Metric'].apply(lambda x: round(x / metrics_count, 2))

metric_category_dist
# Out:
#                  Metric  Percentage
# Metric category
# process             260        0.68
# product             125        0.33
# resources             4        0.01

# %% [markdown]
# Metrics used as action triggers or anomaly indicators

# %%
data.loc[data.loc[data['Metric'].dropna().index][['Anomaly', 'Suggested Action']].dropna(how="all").index][['Metric','Anomaly', 'Suggested Action']].nunique()
# Out:
# Metric              231
# Anomaly             124
# Suggested Action    141
# dtype: int64

# %% [markdown]
# Anomaly-Metric-Action Connection components

# %%
temp = data[['Metric','Anomaly','Suggested Action']].dropna().drop_duplicates()

print(temp.count()[0])

temp.nunique()
# Out:
# 112
# Metric              49
# Anomaly             85
# Suggested Action    89
# dtype: int64

# %% [markdown]
# #### Metrics used as anomaly indicators

# %% [markdown]
# Distribution of software metrics used as anomaly indicators

# %%
temp3 = data.loc[data[['Metric', 'Anomaly']].dropna().index][['Study','Metric']].dropna().drop_duplicates()

metric_study_count = temp3.groupby("Metric").count().sort_values("Study", ascending = False)

temp2 = data.loc[temp3.index]

temp = metric_study_count

temp['Studies'] = None
temp['Citation'] = None

for s in temp.index:
  temp.at[s, 'Studies'] = temp2[temp2['Metric']==s]['Study'].unique()
  temp.at[s, 'Citation'] = study2citation(temp2[temp2['Metric']==s]['Study'].unique())

print(temp.head(10).to_string())
# Out:
#                                        Study                         Studies                                                                                                                  Citation
# Metric
# loc                                        6  [S07, S12, S30, S44, S49, S58]  [porter1990empirically, lane1997intergrating, chowdhury2011using, kumar2017empirical, treude2018unusual, abaei2020fuzzy]
# cyclomatic complexity                      4            [S07, S30, S44, S58]                                           [porter1990empirically, chowdhury2011using, kumar2017empirical, abaei2020fuzzy]
# # change requests                          3                 [S40, S41, S49]                                                                   [korkala2014waste, lavallee2015good, treude2018unusual]
# # defects                                  3                 [S10, S16, S26]                                                         [bhandari1993case, leszak2002classification, tsunoda2010modeling]
# fan-out                                    2                      [S30, S57]                                                                              [chowdhury2011using, kolahdouz2020technical]
# coupling between object classes (cbo)      2                      [S30, S44]                                                                                  [chowdhury2011using, kumar2017empirical]
# response for class (rfc)                   2                      [S30, S44]                                                                                  [chowdhury2011using, kumar2017empirical]
# productivity in function points            2                      [S12, S15]                                                                               [lane1997intergrating, mohapatra2001defect]
# number of children (noc)                   2                      [S30, S44]                                                                                  [chowdhury2011using, kumar2017empirical]
# lack of cohesion of methods (lcom)         2                      [S30, S44]                                                                                  [chowdhury2011using, kumar2017empirical]

# %% [markdown]
# Studies which used 'loc' as anomaly indicator

# %%
studies_metric_anomaly = data.loc[data[['Metric', 'Anomaly']].dropna().drop_duplicates().index][['Study','Metric']].dropna().drop_duplicates().sort_values("Metric")

t = studies_metric_anomaly[studies_metric_anomaly['Metric']=='loc'].sort_values("Study")
t['Mapping'] = t['Study'].map(lambda x: study_mapping[x])
t
# Out:
#      Study Metric                Mapping
# 116    S07    loc  porter1990empirically
# 143    S12    loc   lane1997intergrating
# 497    S30    loc     chowdhury2011using
# 742    S44    loc     kumar2017empirical
# 828    S49    loc      treude2018unusual
# 1608   S58    loc         abaei2020fuzzy

# %% [markdown]
# Study count used metrics as anomaly indicators

# %%
data.loc[data[['Metric', 'Anomaly']].dropna().index][['Study','Metric']].dropna().drop_duplicates()['Study'].nunique()
# Out:
# 27

# %% [markdown]
# Metric count used as anomaly indicators

# %%
data.loc[data[['Metric', 'Anomaly']].dropna().index][['Metric']].dropna().drop_duplicates()['Metric'].nunique()
# Out:
# 155

# %% [markdown]
# Anomaly count detected by metrics

# %%
data.loc[data[['Metric', 'Anomaly']].dropna().index][['Anomaly']].dropna().drop_duplicates()['Anomaly'].nunique()
# Out:
# 124

# %% [markdown]
# Top software metrics ranked by number of anomalies detected

# %%
temp1 = data.loc[data[['Metric', 'Anomaly']].dropna().index][['Metric','Anomaly']].dropna().drop_duplicates()

temp2 = data.loc[temp1.index]

temp3 = temp1.groupby("Metric").count().sort_values("Anomaly", ascending = False).head(10)


temp = temp3

temp['Studies'] = None
temp['Citation'] = None

for s in temp.index:
  temp.at[s, 'Studies'] = temp2[temp2['Metric']==s]['Study'].unique()
  temp.at[s, 'Citation'] = study2citation(temp2[temp2['Metric']==s]['Study'].unique())


print(temp.to_string())
# Out:
#                                               Anomaly                         Studies                                                                                                                  Citation
# Metric
# defect injection metric                            30                           [S33]                                                                                                      [kumaresh2012defect]
# frequnce of interactions, number of meetings       10                           [S41]                                                                                                        [lavallee2015good]
# defect density                                     10                      [S26, S29]                                                                                 [tsunoda2010modeling, kumaresh2010defect]
# loc                                                 7  [S07, S12, S30, S44, S49, S58]  [porter1990empirically, lane1997intergrating, chowdhury2011using, kumar2017empirical, treude2018unusual, abaei2020fuzzy]
# cyclomatic complexity                               4            [S07, S30, S44, S58]                                           [porter1990empirically, chowdhury2011using, kumar2017empirical, abaei2020fuzzy]
# # change requests                                   3                 [S40, S41, S49]                                                                   [korkala2014waste, lavallee2015good, treude2018unusual]
# # defects                                           3                 [S10, S16, S26]                                                         [bhandari1993case, leszak2002classification, tsunoda2010modeling]
# efforts (time spent) in coding                      2                           [S34]                                                                                                      [dalal2013empirical]
# coupling between object classes (cbo)               2                      [S30, S44]                                                                                  [chowdhury2011using, kumar2017empirical]
# depth of inheritance tree (dit)                     2                      [S30, S44]                                                                                  [chowdhury2011using, kumar2017empirical]

# %%
temp
# Out:
#                                               Anomaly  \
# Metric
# defect injection metric                            30
# frequnce of interactions, number of meetings       10
# defect density                                     10
# loc                                                 7
# cyclomatic complexity                               4
# # change requests                                   3
# # defects                                           3
# efforts (time spent) in coding                      2
# coupling between object classes (cbo)               2
# depth of inheritance tree (dit)                     2
#
#                                                                      Studies  \
# Metric
# defect injection metric                                                [S33]
# frequnce of interactions, number of meetings                           [S41]
# defect density                                                    [S26, S29]
# loc                                           [S07, S12, S30, S44, S49, S58]
# cyclomatic complexity                                   [S07, S30, S44, S58]
# # change requests                                            [S40, S41, S49]
# # defects                                                    [S10, S16, S26]
# efforts (time spent) in coding                                         [S34]
# coupling between object classes (cbo)                             [S30, S44]
# depth of inheritance tree (dit)                                   [S30, S44]
#
#                                                                                        Citation
# Metric
# defect injection metric                                                    [kumaresh2012defect]
# frequnce of interactions, number of meetings                                 [lavallee2015good]
# defect density                                        [tsunoda2010modeling, kumaresh2010defect]
# loc                                           [porter1990empirically, lane1997intergrating, ...
# cyclomatic complexity                         [porter1990empirically, chowdhury2011using, ku...
# # change requests                             [korkala2014waste, lavallee2015good, treude201...
# # defects                                     [bhandari1993case, leszak2002classification, t...
# efforts (time spent) in coding                                             [dalal2013empirical]
# coupling between object classes (cbo)                  [chowdhury2011using, kumar2017empirical]
# depth of inheritance tree (dit)                        [chowdhury2011using, kumar2017empirical]

# %% [markdown]
# Studies of 'loc' used as anomaly indicator

# %%
temp = data.loc[data.loc[data[['Metric', 'Anomaly']].dropna().drop_duplicates().index][['Metric','Anomaly']].dropna().drop_duplicates().index]['Metric']


temp2 = data.loc[temp[temp=='loc'].index][['Study','Metric']].dropna().drop_duplicates()
temp2['citation'] = [study_mapping[k] for k in temp2['Study']]

temp2
# Out:
#      Study Metric               citation
# 116    S07    loc  porter1990empirically
# 143    S12    loc   lane1997intergrating
# 497    S30    loc     chowdhury2011using
# 742    S44    loc     kumar2017empirical
# 828    S49    loc      treude2018unusual
# 1608   S58    loc         abaei2020fuzzy

# %% [markdown]
# Studies of 'cyclomatic complexity' used as anomaly indicator

# %%
temp = data.loc[data.loc[data[['Metric', 'Anomaly']].dropna().drop_duplicates().index][['Metric','Anomaly']].dropna().drop_duplicates().index]['Metric']


temp2 = data.loc[temp[temp=='cyclomatic complexity'].index][['Study','Metric']].dropna().drop_duplicates()
temp2['citation'] = [study_mapping[k] for k in temp2['Study']]

temp2
# Out:
#      Study                 Metric               citation
# 114    S07  cyclomatic complexity  porter1990empirically
# 491    S30  cyclomatic complexity     chowdhury2011using
# 750    S44  cyclomatic complexity     kumar2017empirical
# 1609   S58  cyclomatic complexity         abaei2020fuzzy

# %% [markdown]
# #### Metrics used as action triggers

# %% [markdown]
# Metric count used as action triggers

# %%
# temp = data.loc[data.loc[data[data.isna()['Anomaly']].index][['Suggested Action','Metric']].dropna().drop_duplicates().index][['Metric']].dropna().drop_duplicates()
# 
temp = data.loc[data[['Suggested Action','Metric']].dropna().drop_duplicates().index][['Metric']].dropna().drop_duplicates()

temp.count()[0]
# Out:
# 125

# %% [markdown]
# Studies used metrics as action triggers

# %%
# temp = data.loc[data.loc[data[data.isna()['Anomaly']].index][['Suggested Action','Metric']].dropna().drop_duplicates().index][['Study']].dropna().drop_duplicates()

temp = data.loc[data[['Suggested Action','Metric']].dropna().drop_duplicates().index][['Study']].dropna().drop_duplicates()

temp = [study_mapping[k] for k in temp['Study']]

temp, len(temp)
# Out:
# (['nassar1986software',
#   'fox1989performance',
#   'bhandari1993case',
#   'zage1995avoiding',
#   'lane1997intergrating',
#   'ebert1999technical',
#   'mohapatra2001defect',
#   'leszak2002classification',
#   'jalote2005using',
#   'wang2006bsr',
#   'tsunoda2010modeling',
#   'kumaresh2010defect',
#   'kumaresh2012experimental',
#   'kumaresh2012defect',
#   'oyetoyan2013study',
#   'korkala2014waste',
#   'lavallee2015good',
#   'hu2017defect',
#   'brito2018investigating'],
#  19)

# %% [markdown]
# Action count which are triggered by metrics

# %%
temp = data.loc[data[['Suggested Action','Metric']].dropna().drop_duplicates().index][['Suggested Action']].dropna().drop_duplicates()

# temp = data.loc[data.loc[data[data.isna()['Anomaly']].index][['Suggested Action','Metric']].dropna().drop_duplicates().index][['Suggested Action']].dropna().drop_duplicates()


temp.count()[0]
# Out:
# 141

# %% [markdown]
# Action category which are triggered by metrics

# %%
temp = data.loc[data[['Suggested Action','Metric']].dropna().drop_duplicates().index][['Suggested Action']].dropna().drop_duplicates()

# temp = data.loc[data.loc[data[data.isna()['Anomaly']].index][['Suggested Action','Metric']].dropna().drop_duplicates().index][['Suggested Action']].dropna().drop_duplicates()

temp1 = data.loc[temp.index][['Suggested Action', 'Action category']]
temp2 = temp1.groupby("Action category").count()

temp2
# Out:
#                  Suggested Action
# Action category
# corrective                     30
# enhancement                    56
# preventive                     54

# %% [markdown]
# Metric categories used as action triggers

# %%
# temp = data.loc[data.loc[data[data.isna()['Anomaly']].index][['Suggested Action','Metric']].dropna().drop_duplicates().index][['Metric']].dropna().drop_duplicates()

temp = data.loc[data[['Suggested Action','Metric']].dropna().drop_duplicates().index][['Metric']].dropna().drop_duplicates()

data.loc[temp.index][["Metric category", "Metric"]].drop_duplicates().dropna().groupby("Metric category").count()
# Out:
#                  Metric
# Metric category
# process             109
# product              16

# %% [markdown]
# Distribution of metrics used as action triggers of category preventive or corrective

# %%
# data.loc[data.loc[data[data.isna()['Anomaly']].index][['Suggested Action','Metric']].dropna().index][['Study', 'Metric']].drop_duplicates().dropna().groupby("Metric").count().sort_values("Study")

# Take into account only 'preventive' and 'corrective' actions, so we remove 'enhancement' actions.
temp0 = data['Action category'].dropna()
temp01 = data.loc[temp0.index]['Action category']
temp0 = temp01[temp01!='enhancement']
temp0 = data.loc[temp0.index]
# temp0 = data

# Select all data which has both metrics and actions.
temp1 = data.loc[temp0[['Suggested Action','Metric']].dropna().index][['Study', 'Metric']].drop_duplicates().dropna()

temp2 = data.loc[temp1.index]

# Group by Metric and count studies.
temp3 = temp1.groupby("Metric").count().sort_values("Study",ascending  = False).head(10)


temp = temp3

temp['Studies'] = None
temp['Citation'] = None

for s in temp.index:
  temp.at[s, 'Studies'] = temp2[temp2['Metric']==s]['Study'].unique()
  temp.at[s, 'Citation'] = study2citation(temp2[temp2['Metric']==s]['Study'].unique())

# temp1
print(temp.to_string())
# temp0
# Out:
#                                               Study          Studies                                                           Citation
# Metric
# # defects                                         3  [S10, S16, S26]  [bhandari1993case, leszak2002classification, tsunoda2010modeling]
# # change requests                                 2       [S40, S41]                               [korkala2014waste, lavallee2015good]
# defect density                                    2       [S26, S29]                          [tsunoda2010modeling, kumaresh2010defect]
# # capability defects                              1            [S10]                                                 [bhandari1993case]
# number of 'team historians'                       1            [S41]                                                 [lavallee2015good]
# defects in release                                1            [S15]                                              [mohapatra2001defect]
# depend on cycle                                   1            [S35]                                                [oyetoyan2013study]
# documentation size                                1            [S41]                                                 [lavallee2015good]
# effort                                            1            [S15]                                              [mohapatra2001defect]
# frequnce of interactions, number of meetings      1            [S41]                                                 [lavallee2015good]

# %% [markdown]
# <!-- No commonly used metrics as action triggers -->
#
# Commonly used metrics as action triggers exist

# %% [markdown]
# Distribution of metrics used as action triggers of category enhancement

# %%
# data.loc[data.loc[data[data.isna()['Anomaly']].index][['Suggested Action','Metric']].dropna().index][['Study', 'Metric']].drop_duplicates().dropna().groupby("Metric").count().sort_values("Study")

# Take into account only 'preventive' and 'corrective' actions, so we remove 'enhancement' actions.
temp0 = data['Action category'].dropna()
temp01 = data.loc[temp0.index]['Action category']
temp0 = temp01[temp01=='enhancement']
temp0 = data.loc[temp0.index]
# temp0 = data

# Select all data which has both metrics and actions.
temp1 = data.loc[temp0[['Suggested Action','Metric']].dropna().index][['Study', 'Metric']].drop_duplicates().dropna()


aa = temp0.drop_duplicates()
print("Number of enhancement actions triggered by metric 'productivity in function points' in 2 studies > ", len(aa[aa['Metric'] == 'productivity in function points']))
# print()

temp2 = data.loc[temp1.index]

# Group by Metric and count studies.
temp3 = temp1.groupby("Metric").count().sort_values("Study",ascending  = False).head(10)


temp = temp3

temp['Studies'] = None
temp['Citation'] = None

for s in temp.index:
  temp.at[s, 'Studies'] = temp2[temp2['Metric']==s]['Study'].unique()
  temp.at[s, 'Citation'] = study2citation(temp2[temp2['Metric']==s]['Study'].unique())


print(temp.to_string())
# Out:
# Number of enhancement actions triggered by metric 'productivity in function points' in 2 studies >  14
#                                  Study     Studies                                        Citation
# Metric
# productivity in function points      2  [S12, S51]  [lane1997intergrating, brito2018investigating]
# actual procurement time              1       [S51]                        [brito2018investigating]
# review duration                      1       [S51]                        [brito2018investigating]
# review speed                         1       [S51]                        [brito2018investigating]
# review rate                          1       [S51]                        [brito2018investigating]
# review preparation rate              1       [S51]                        [brito2018investigating]
# review performance                   1       [S51]                        [brito2018investigating]
# review efficiency                    1       [S51]                        [brito2018investigating]
# review effectiveness                 1       [S51]                        [brito2018investigating]
# review duration per defect           1       [S51]                        [brito2018investigating]

# %% [markdown]
# Top software metrics ranked by number of actions suggested

# %%
# temp1 = data['Anomaly'].isna()
# data[temp1]


temp2 = data['Action category'].dropna()

temp3 = data.loc[temp2[temp2 != 'enhancement'].index]

temp4 = temp3[['Metric','Suggested Action',"Action category"]].dropna()

temp5 = temp4.groupby(["Metric","Action category"]).count().sort_values(["Suggested Action","Action category"],ascending = False)

temp5.head(10)

# study2citation(data.loc[temp4.index]['Study'].unique())
# Out:
#                                                               Suggested Action
# Metric                                       Action category
# defect injection metric                      preventive                     30
# defect density                               preventive                     19
# frequnce of interactions, number of meetings corrective                     10
# defect density                               corrective                      4
# # defects                                    corrective                      3
# # change requests                            corrective                      2
# # identified errors                          preventive                      1
# # identified faults                          preventive                      1
# # lapses                                     preventive                      1
# # number of human mistakes                   preventive                      1

# %% [markdown]
# ### Anomaly Data

# %% [markdown]
# Anomaly count

# %%
data.loc[data['Anomaly'].dropna().drop_duplicates().index]['Anomaly'].nunique()
# Out:
# 374

# %% [markdown]
# Root Causes count

# %%
data.loc[data['Anomaly'].dropna().drop_duplicates().index]['Root causes'].dropna().drop_duplicates().nunique()
# Out:
# 142

# %% [markdown]
# Study count which provides anomaly data

# %%
data.loc[data[['Study','Anomaly']].dropna().drop_duplicates().index][['Study']].dropna().drop_duplicates().nunique()
# Out:
# Study    45
# dtype: int64

# %% [markdown]
# Top software anomalies ranked by the number of suggested actions

# %%
temp1 = data[['Anomaly', 'Suggested Action', "Action category"]].dropna()

temp2 = temp1.drop_duplicates()
#"Action category"
temp3 = temp2.groupby(["Anomaly"]).count().sort_values(["Suggested Action"], ascending = False)

temp4 = temp2.groupby(["Anomaly", "Action category"]).count().sort_values(["Suggested Action"], ascending = False)


temp3.head(10)
# temp4.index = temp4.index.swaplevel(0, 1)
# temp4.sort_index(axis = 1, level=['Anomaly', 'Action category']).sortlevel()

temp5 = temp4.reset_index(1)

temp6 = temp5.reset_index()

temp5['Total action'] = temp6[['Anomaly','Suggested Action']].groupby("Anomaly").sum()
# temp5[['Anomaly','Suggested Action']].groupby("Anomaly").sum()
# temp5

temp5.head(10)
# Out:
#                                                    Action category  \
# Anomaly
# resistance to change                                    preventive
# inaccurate estimation of efforts                        corrective
# systemic defects into software.                         preventive
# insufficient development work outcome                   corrective
# a lot of bugs encountered                               corrective
# oversight issue                                         preventive
# the technical activities needed in a particular...      corrective
# casual defects of operations and others                 preventive
# lack of information on how the system should work       corrective
# vague customer needs                                    preventive
#
#                                                     Suggested Action  \
# Anomaly
# resistance to change                                              27
# inaccurate estimation of efforts                                  15
# systemic defects into software.                                   11
# insufficient development work outcome                             10
# a lot of bugs encountered                                         10
# oversight issue                                                    8
# the technical activities needed in a particular...                 7
# casual defects of operations and others                            5
# lack of information on how the system should work                  5
# vague customer needs                                               4
#
#                                                     Total action
# Anomaly
# resistance to change                                          29
# inaccurate estimation of efforts                              15
# systemic defects into software.                               12
# insufficient development work outcome                         10
# a lot of bugs encountered                                     10
# oversight issue                                                8
# the technical activities needed in a particular...             7
# casual defects of operations and others                        5
# lack of information on how the system should work              5
# vague customer needs                                           4

# %% [markdown]
# Top software anomalies ranked by number of metrics used in detection

# %%
temp1 = data[['Anomaly','Metric']].dropna().drop_duplicates()
temp2 = temp1.groupby("Anomaly").count().sort_values("Metric", ascending = False).reset_index()
print(temp2.head(15).to_string())
# Out:
#                                                                                                                                                                                                       Anomaly  Metric
# 0                                                                                                                                                                                            ci build failure      33
# 1                                                                                                                                                           the class in objected oriented software is faulty      18
# 2                                                                                                                                                                             vulnerability files in software      13
# 3                                                                                                                                                                                        unusual pull request      10
# 4                                                                                                                                                                                              unusual commit       9
# 5                                                                                                                                                                                         fault-prone classes       6
# 6                                                                                                                                                                                        unusual github issue       6
# 7                                                                                                                                                                                        high risk components       4
# 8                                                                                                                                                                 a cyclic group of components in oo software       3
# 9            the team will lose all knowledge of the beginning of the project, including details on the requirements and analysis phases. \ndocumentation of the module will be incomplete and/or inaccurate.       3
# 10                                                                                                                                                                                          functional defect       3
# 11                                                                                                                                                     nonfunctional areas of design not adequately addressed       3
# 12  the issuers of the orders and threats might not have all relevant information which could results in ill-defined priorities.\nbypassing the normal team structure undermines its decision-making process.       2
# 13                                                                                                                                                        vulnerability testing is performed late and quickly       2
# 14                                                                                      project constraints means that teams must protect the scope of their project against change requests from other teams       2

# %% [markdown]
# ### Actions Data

# %% [markdown]
# Action count

# %%
data.loc[data['Suggested Action'].dropna().drop_duplicates().index]['Suggested Action'].nunique()
# Out:
# 494

# %%
action_count = data.loc[data['Suggested Action'].dropna().drop_duplicates().index][['Suggested Action', 'Action category']].dropna().drop_duplicates().nunique()
temp = data.loc[data['Suggested Action'].dropna().drop_duplicates().index][['Suggested Action', 'Action category']].dropna().drop_duplicates().groupby("Action category").count()

temp['Percentage'] = temp['Suggested Action'] / action_count[0]

temp
# Out:
#                  Suggested Action  Percentage
# Action category
# corrective                    175    0.354970
# enhancement                    68    0.137931
# preventive                    250    0.507099

# %% [markdown]
# Action count in CMMI key process areas

# %%
temp1 = data[['Suggested Action', 'CMMI']].dropna().drop_duplicates()

temp1.groupby("CMMI").count().sort_values("CMMI")
# Out:
#                                           Suggested Action
# CMMI
# casual analysis and resolution                           3
# configuration management                                16
# integrated project management                           96
# measurement and analysis                                 4
# organizational innovation and deployment                 1
# organizational process definition                       13
# organizational process focus                            39
# organizational process performance                      12
# organizational training                                 36
# process and product quality assurance                   23
# product integration                                     12
# project monitoring and control                          11
# project planning                                        14
# quantitative project management                          1
# requirements developments                               19
# requirements management                                 42
# risk management                                         16
# supplier agreement management                            2
# technical solution                                      72
# validation                                              23
# verification                                            38

# %% [markdown]
# Top preventive and corrective actions ranked by the number of metrics used in triggering the action

# %%
temp = data['Action category'].dropna()

temp = temp[temp!='enhancement']

temp1 = data.loc[temp.index][['Suggested Action', 'Metric']].dropna().drop_duplicates()

temp2 = temp1.groupby("Suggested Action").count().sort_values("Metric", ascending = False)
print(temp2.head(10).reset_index().to_string())
# Out:
#                                                                                                                                                                          Suggested Action  Metric
# 0                                                                                                                                   train developers to understand the requirement errors       6
# 1                                                                                                                                      emphasize nonfunctional areas in succeeding phases       3
# 2                                                                                                                                reduce or avoid cyclic dependencies in depelopment stage       3
# 3  team members should make sure that knowledge is appropriately distributed amongst them.  for example, pair programming, code review are practices which can promote knowledge sharing.       3
# 4                                                               once a project is completed, the team must ensure that the “what” and “why” of each software item are properly documented       2
# 5                                                                  make sure that the development team is aware of the cmmi-acq or iso12207 processes for negotiating with third parties.       2
# 6                  plan organization-wide process reviews to detect isolated processes and to promote information flows between processes. post-mortems for detecting missing information       2
# 7                                                                 planned special budget items to support long lasting corrections or corrections that are likely to benefit many modules       2
# 8                                                                                                                                                 have a team of cross functional experts       2
# 9                                                                 make sure that testers are involved when negotiating with a third party for a potentially vulnerable software component       2

# %% [markdown]
# Action count suggested for fixing anomalies

# %%
# data[data[['Action category']]=='enhancement']['Anomaly'].dropna()

temp1 = data[['Anomaly', 'Suggested Action']].dropna().drop_duplicates()
print(temp1.count()[0])
temp1.nunique()
# Out:
# 409
# Anomaly             224
# Suggested Action    360
# dtype: int64

# %% [markdown]
# # Display Data as a Graph

# %% [markdown]
# ##Build Graph

# %% [markdown]
# Get all data types

# %%
col = metrics_col_name

def getvalues(data=data, cols=[metrics_col_name]) :
    #if cols[0] in data.columns:
  #  for col in cols
        #print(67)
        return data.dropna(subset=cols)[cols]
        #return pd.unique(data.loc[data.where(, cols]) 

metrics = getvalues(data, [metrics_col_name])[metrics_col_name].tolist()
#print(metrics)
anomalies = getvalues(data, [anomalies_col_name] )[anomalies_col_name].tolist() 
actions = getvalues(data, [actions_col_name] )[actions_col_name].tolist() 

len(metrics)
#print(anomalies['Anomaly'].tolist()) 

#graph.add_nodes(metrics) # color = ["blue" for x in range(len(metrics)) ])
#graph.add_nodes(anomalies) 
#graph.add_nodes(actions)
#graph.add_edge(



#show_graph()
#len(graph.get_nodes()), len(graph.get_edges())
# Out:
# 588

# %% [markdown]
# Get Only connected data

# %%
connected = getvalues(data, [metrics_col_name, anomalies_col_name, actions_col_name])

connected
# Out:
#                                                 Metric  \
# 71   ratio of the performance gain to the effort af...
# 129                                          # defects
# 130                               # capability defects
# 131                              # performance defects
# 132                                # usability defects
# ..                                                 ...
# 800                                # identified faults
# 801                                            # slips
# 802                                           # lapses
# 803                         # number of human mistakes
# 804                                    # people errors
#
#                                                Anomaly  \
# 71   incorrect, inexact or overconstraining interpr...
# 129             lack of communication between subteams
# 130  nonfunctional areas of design not adequately a...
# 131  nonfunctional areas of design not adequately a...
# 132  nonfunctional areas of design not adequately a...
# ..                                                 ...
# 800  developer forgets a goal in the middle of a se...
# 801  developer commits planning errors such that s/...
# 802    cognitive bias among developers (people errors)
# 803  the team selects the inappropriate process for...
# 804  the team commits mistakes in organizing and sp...
#
#                                       Suggested Action
# 71   active participation of project system enginee...
# 129  repeat inspections, teach-the-team sessions du...
# 130  emphasize nonfunctional areas in succeeding ph...
# 131  emphasize nonfunctional areas in succeeding ph...
# 132  emphasize nonfunctional areas in succeeding ph...
# ..                                                 ...
# 800  train developers to understand the requirement...
# 801  train developers to understand the requirement...
# 802  train developers to understand the requirement...
# 803  train developers to understand the requirement...
# 804  train developers to understand the requirement...
#
# [117 rows x 3 columns]

# %% [markdown]
# ## Draw Graph

# %%
def multilayered_graph(cols, *subset_sizes):

    l = {metrics_col_name:0, anomalies_col_name:1, actions_col_name:2}


    connected = getvalues(data, cols)


    for i in range(len(cols)):

        nodes = connected.iloc[:,i]

        G.add_nodes_from(nodes, layer=l[cols[i]], group=l[cols[i]]) # , s = node_shapes[cols[i]]

    for _, item in connected.iterrows():

      for i in cols:
        for j in range(1, len(cols)):
          if (not pd.isna(item[cols[j]]) and 
              not pd.isna(item[cols[j-1]]) and 
              not G.has_edge(item[cols[j-1]], item[cols[j]])
              ):
            if (not nx.is_simple_path(G, [item[cols[j-1]], item[cols[j]]])):
              G.add_edge(item[cols[j-1]], item[cols[j]])

    return G



subset_sizes = [metrics, anomalies, actions]

print(metrics, anomalies, actions)
subset_color = [
    "blue",
    "red",
    "green",
]


G = nx.Graph()


cols = [metrics_col_name, anomalies_col_name, actions_col_name]
G = multilayered_graph(cols, *subset_sizes)


cols = [metrics_col_name, anomalies_col_name]
G = multilayered_graph(cols, *subset_sizes)


cols = [anomalies_col_name, actions_col_name]
G = multilayered_graph(cols, *subset_sizes)


cols = [metrics_col_name, actions_col_name]
G = multilayered_graph(cols, *subset_sizes)

color = [subset_color[d["layer"]] for v,d in G.nodes(data=True) if 'layer' in d]



k = 0.06

layout = nx.spring_layout(G, k = k)#, k=0.4)

# layout = nx.shell_layout(G)#, k=0.4)

# layout = nx.random_layout(G)
# layout = None

# layout = nx.spectral_layout(G)
# layout = nx.nx_pydot.graphviz_layout(G)
# layout = nx.kamada_kawai_layout(G)

# layout = nx.multipartite_layout(G, subset_key="layer")

# layout1 = nx.circular_layout(G)


import matplotlib.patches as mpatches


blue_patch = mpatches.Patch(color='blue', label='Metrics')
red_patch = mpatches.Patch(color='red', label='Anomalies')
green_patch = mpatches.Patch(color='green', label='Actions')

# layout = nx.multipartite_layout(G, subset_key="layer")
plt.figure(figsize=(100, 100))

plt.legend(handles = [blue_patch, red_patch, green_patch],prop={'size': 80})



# nx.draw_networkx_nodes(G, pos = layout, node_color=color, node_size=100, linewidths = 10)
# nx.draw_networkx_edges(G, pos = layout)
nx.draw(G, pos = layout, node_color=color, with_labels=False, node_size=600) #, edgecolors = "black", )

plt.savefig("Graph.svg", format="SVG", bbox_inches = 'tight')

# plt.axis("equal")
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Graph for Latex

# %%
graph = G
nodes = graph.nodes
# print(list(nodes))
if 'label' in list(nodes)[0]:
  nodes = list(map(lambda x: x['label'], nodes))
else:
  nodes = list(map(lambda x: x, nodes))

edges = graph.edges

if 'from' in list(edges)[0]:
  edges = list(map(lambda x: (x['from'], x['to']), edges))
else: 
  edges = list(map(lambda x: (x[0], x[1]), edges))




node_colors = list(dict(G.nodes(data='group')).values())

style = {}
style['node_opacity'] = .5
style['edge_curved'] = .1
style['vertex_size'] = .01
style['vertex_label'] = {}
style['node_color'] = [subset_color[g] for g in node_colors]
# style['node_color'] = node_colors



plot((nodes,edges), 'network.tex', **style)

# %% [markdown]
# ### Show graph in HTML

# %%
def show_graph(graph, w = '500px', h = '500px', title="sample.html"):
   # graph.show_buttons(filter_=['physics'])
   nt = Network(w, h)
   nt.from_nx(graph)
   nt.show(title)
  
   display(HTML(title))

show_graph(graph, title = "index.html")
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis.css" type="text/css" />
# <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 500px;
#             height: 500px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#         #loadingBar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width: 500px;
#             height: 500px;
#             background-color:rgba(200,200,200,0.8);
#             -webkit-transition: all 0.5s ease;
#             -moz-transition: all 0.5s ease;
#             -ms-transition: all 0.5s ease;
#             -o-transition: all 0.5s ease;
#             transition: all 0.5s ease;
#             opacity:1;
#         }
#
#         #bar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width:20px;
#             height:20px;
#             margin:auto auto auto auto;
#             border-radius:11px;
#             border:2px solid rgba(30,30,30,0.05);
#             background: rgb(0, 173, 246); /* Old browsers */
#             box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#         }
#
#         #border {
#             position:absolute;
#             top:10px;
#             left:10px;
#             width:500px;
#             height:23px;
#             margin:auto auto auto auto;
#             box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#             border-radius:10px;
#         }
#
#         #text {
#             position:absolute;
#             top:8px;
#             left:530px;
#             width:30px;
#             height:50px;
#             margin:auto auto auto auto;
#             font-size:22px;
#             color: #000000;
#         }
#
#         div.outerBorder {
#             position:relative;
#             top:400px;
#             width:600px;
#             height:44px;
#             margin:auto auto auto auto;
#             border:8px solid rgba(0,0,0,0.1);
#             background: rgb(252,252,252); /* Old browsers */
#             background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#             background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#             background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#             background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#             background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#             background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#             filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#             border-radius:72px;
#             box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#         }
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
# <div id="loadingBar">
#     <div class="outerBorder">
#         <div id="text">0%</div>
#         <div id="border">
#             <div id="bar"></div>
#         </div>
#     </div>
# </div>
#
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"group": 0, "id": "ratio of the performance gain to the effort after a careful reappraisal of requirements", "label": "ratio of the performance gain to the effort after a careful reappraisal of requirements", "layer": 0, "shape": "dot", "size": 10}, {"group": 1, "id": "incorrect, inexact or overconstraining interpretations of direct or derived* requirements", "label": "incorrect, inexact or overconstraining interpretations of direct or derived* requirements", "layer": 1, "shape": "dot", "size": 10}, {"group": 2, "id": "active participation of project system engineers who know the origin of requirements interpretations", "label": "active participation of project system engineers who know the origin of requirements interpretations", "layer": 2, "shape": "dot", "size": 10}, {"group": 0, "id": "# defects", "label": "# defects", "layer": 0, "shape": "dot", "size": 10}, {"group": 1, "id": "lack of communication between subteams", "label": "lack of communication between subteams", "layer": 1, "shape": "dot", "size": 10}, {"group": 1, "id": "defects in component specification and design documentation", "label": "defects in component specification and design documentation", "layer": 1, "shape": "dot", "size": 10}, {"group": 1, "id": "software reliability growth model estimates remaining defects as high", "label": "software reliability growth model estimates remaining defects as high", "layer": 1, "shape": "dot", "size": 10}, {"group": 2, "id": "repeat inspections, teach-the-team sessions during main project", "label": "repeat inspections, teach-the-team sessions during main project", "layer": 2, "shape": "dot", "size": 10}, {"group": 2, "id": "ensure required contents, especially include compliance to non-functional and performance requirements,", "label": "ensure required contents, especially include compliance to non-functional and performance requirements,", "layer": 2, "shape": "dot", "size": 10}, {"group": 2, "id": "testing is proceeded until the srgm estimates remaining defects as low", "label": "testing is proceeded until the srgm estimates remaining defects as low", "layer": 2, "shape": "dot", "size": 10}, {"group": 0, "id": "# capability defects", "label": "# capability defects", "layer": 0, "shape": "dot", "size": 10}, {"group": 1, "id": "nonfunctional areas of design not adequately addressed", "label": "nonfunctional areas of design not adequately addressed", "layer": 1, "shape": "dot", "size": 10}, {"group": 2, "id": "emphasize nonfunctional areas in succeeding phases", "label": "emphasize nonfunctional areas in succeeding phases", "layer": 2, "shape": "dot", "size": 10}, {"group": 0, "id": "# performance defects", "label": "# performance defects", "layer": 0, "shape": "dot", "size": 10}, {"group": 0, "id": "# usability defects", "label": "# usability defects", "layer": 0, "shape": "dot", "size": 10}, {"group": 0, "id": "association among functions in cldp phase", "label": "association among functions in cldp phase", "layer": 0, "shape": "dot", "size": 10}, {"group": 1, "id": "component-level design done at module-level design--prototype project (mldp) on discovery of missing requirements.", "label": "component-level design done at module-level design--prototype project (mldp) on discovery of missing requirements.", "layer": 1, "shape": "dot", "size": 10}, {"group": 2, "id": "reinspect requirements document before proceeding further", "label": "reinspect requirements document before proceeding further", "layer": 2, "shape": "dot", "size": 10}, {"group": 0, "id": "# defects in new function found mainly in cldp versus rewritten in mldp", "label": "# defects in new function found mainly in cldp versus rewritten in mldp", "layer": 0, "shape": "dot", "size": 10}, {"group": 1, "id": "incosistent classification of source by project team", "label": "incosistent classification of source by project team", "layer": 1, "shape": "dot", "size": 10}, {"group": 2, "id": "consistent defini
